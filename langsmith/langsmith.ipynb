# %% [markdown]
# - cheack pointer in lang graph help u to imlement short term memory in langgraph
# - u store your graph state at every state
# - we will make thread and store that memory some where
# - at first we will store it in ram
# - as we store the data in ram the data will be vanished so to solve this problem we will store it in some database

# %% [markdown]
# - we are using in memory svaer to implement the graph
# - we will make the config variable and then store our graph in it

# %% [markdown]
# there are two value
# - persistance >> machine >> langgraph
# - docker >> postgrace >> langraph

# %% [markdown]
# - we will install docker first
# - we need all this dependance like
# ```
# !pip install -U \
#   langgraph \
#   langgraph-checkpoint-postgres \
#   psycopg[binary,pool] \
#   langchain-openai
# ```

# %%
import os

os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_ENDPOINT"] = "https://api.smith.langchain.com"
os.environ["LANGCHAIN_API_KEY"] = "lsv2.................."
os.environ["LANGCHAIN_PROJECT"] = "langsmith-demo"

# %%
import langchain
import langsmith

print(langchain.__version__)
print(langsmith.__version__)
# Out:
# 1.3.13
# 0.10.3

# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser


# Simple one-line prompt
prompt = PromptTemplate.from_template("{question}")

model = ChatGroq(
    model="llama-3.3-70b-versatile",
    api_key="..."
)
parser = StrOutputParser()

# Chain: prompt → model → parser
chain = prompt | model | parser

# Run it
result = chain.invoke({"question": "What is the capital of delhi?"})
print(result)
# Out:
# Delhi is actually a state (also known as the National Capital Territory of Delhi) in India, and it does not have a capital. Instead, Delhi itself serves as the capital of India. The city of Delhi is home to the Indian government and many important institutions, and it is often referred to as the capital city of India.
#
# So, to clarify, there is no separate capital of Delhi, as Delhi is already the capital of India!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
